# %% [markdown]
# #### Objective: Sentiment Analysis on Neighborhood Review Data

# %% [markdown]
# ##### Step 1: Load required libraries/ modeules

# %%
# pip install transformers

# %%
# pip install torch

# %%
# import packages
import pandas as pd

import re
import pandas as pd
from typing import List

import nltk
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
# Download the set of stop words
# nltk.download('stopwords')
# nltk.download('punkt')

from sklearn.feature_extraction.text import CountVectorizer

from transformers import DistilBertTokenizer, TFDistilBertForSequenceClassification

from transformers import pipeline
import torch

# %% [markdown]
# ##### Step 2: Read and setup the dataset and print the details of the first review

# %%
file_path = 'data/4_sentimentAnalysis/Neighborhood_Review.csv'
# Read the CSV file into a DataFrame.
df = pd.read_csv(file_path)
# Print the dimensions of the DataFrame
print(df.shape)
df.head(1)
# Out:
# (207, 6)
#                                  userID          userType  \
# 0  70017df6-e055-4776-8c48-7347a2b2be44  Current Resident
#
#                    createdTime          categories  rating  \
# 0  2017-05-02T17:05:51.560792Z  Overall Experience       3
#
#                                               review
# 0  The community is changing with lots of diversi...

# %% [markdown]
# ##### Step 3: Creatig ground truth based on the rating
# The rating is in the range of [1, 5], and we convert it into -1 (1 or 2 stars), 0 (3 stars) and 1 (4 or 5 stars).

# %%
# Function to convert rating to ground_truth
def convert_rating(rating):
    if rating in [1, 2]:
        return -1
    elif rating == 3:
        return 0
    elif rating in [4, 5]:
        return 1

# Apply this function to the 'rating' column to create a new 'ground_truth' column
df['ground_truth'] = df['rating'].apply(convert_rating)
df.head(5)
# Out:
#                                  userID          userType  \
# 0  70017df6-e055-4776-8c48-7347a2b2be44  Current Resident
# 1  0c0ff133-4b8b-40a0-ba9d-bbf05eb9d8db  Current Resident
# 2  5f2ee6d6-f1ad-4350-b0b1-bc8ba99177bb  Current Resident
# 3  04ee54e1-8876-4b1e-8d99-336782962398  Current Resident
# 4  5ebe6d64-83d8-49f9-bb46-d3de859bb43d  Current Resident
#
#                    createdTime          categories  rating  \
# 0  2017-05-02T17:05:51.560792Z  Overall Experience       3
# 1  2017-03-28T20:01:57.185719Z  Overall Experience       4
# 2  2017-03-15T00:18:32.329913Z  Overall Experience       5
# 3  2017-02-21T16:13:09.569592Z  Overall Experience       5
# 4  2017-02-01T22:24:32.521606Z  Overall Experience       5
#
#                                               review  ground_truth
# 0  The community is changing with lots of diversi...             0
# 1  I have lived here for over 8 years. I basicall...             1
# 2  I've lived here for almost two years and love ...             1
# 3  I was born and raised in this neighborhood. Th...             1
# 4  The neighborhood I live in is very calm;not to...             1

# %% [markdown]
# ##### Step 4: Preprocess the data

# %%
# Function to preprocess text
def preprocess_text(text: str) -> str:
    # Convert text to lowercase
    text = text.lower()
    # Remove punctuation
    text = re.sub(r'[^\w\s]', '', text)
    # Remove numbers
    text = re.sub(r'\d+', '', text)
    # Remove extra whitespace
    text = text.strip()
    # Remove abbreviation
    text = re.sub(r'\b(?:[a-zA-Z]\.){2,}', '', text)
    return text

# %%
df['processed_review'] = df['review'].apply(preprocess_text)

#print(df[['review', 'processed_review']])
df.head(15)
# Out:
#                                   userID          userType  \
# 0   70017df6-e055-4776-8c48-7347a2b2be44  Current Resident
# 1   0c0ff133-4b8b-40a0-ba9d-bbf05eb9d8db  Current Resident
# 2   5f2ee6d6-f1ad-4350-b0b1-bc8ba99177bb  Current Resident
# 3   04ee54e1-8876-4b1e-8d99-336782962398  Current Resident
# 4   5ebe6d64-83d8-49f9-bb46-d3de859bb43d  Current Resident
# 5   9eed36d9-97a1-4bc8-be77-7d88c6995632  Current Resident
# 6   e06aadd9-20a9-4f6c-9081-662e88488b67  Current Resident
# 7   8c0e0ecd-49e0-4501-9c76-8889e1543c5e  Current Resident
# 8   3f475785-83e0-4d3b-9267-96a4fe0a1414   Former Resident
# 9   ad77ae98-9f7a-4790-a6db-940506d1160e  Current Resident
# 10  af9ef115-e900-42a5-a9ff-bf52ce761e15  Current Resident
# 11  91ea7277-2b9f-4530-805a-b378c929a2db        Niche User
# 12  718e6fee-f205-4b3c-94b1-f0cbc40e3dda        Niche User
# 13  ca0b75a2-5605-4789-a7fb-1833f926a55f        Niche User
# 14  99a66f15-d937-4d8f-a20b-21b0a9bc7212        Niche User
#
#                     createdTime          categories  rating  \
# 0   2017-05-02T17:05:51.560792Z  Overall Experience       3
# 1   2017-03-28T20:01:57.185719Z  Overall Experience       4
# 2   2017-03-15T00:18:32.329913Z  Overall Experience       5
# 3   2017-02-21T16:13:09.569592Z  Overall Experience       5
# 4   2017-02-01T22:24:32.521606Z  Overall Experience       5
# 5   2017-01-11T22:13:59.439074Z  Overall Experience       5
# 6   2016-12-04T14:26:07.351541Z  Overall Experience       2
# 7   2016-11-23T18:30:22.405976Z  Overall Experience       3
# 8   2016-10-25T17:30:50.394406Z  Overall Experience       4
# 9   2016-10-21T18:29:28.691208Z  Overall Experience       4
# 10  2016-10-06T00:59:20.874513Z  Overall Experience       4
# 11         2016-09-18T01:21:30Z         Real Estate       4
# 12         2016-09-18T01:20:28Z           Community       4
# 13         2016-09-18T01:00:03Z      Crime & Safety       3
# 14         2016-09-18T00:58:26Z  Overall Experience       3
#
#                                                review  ground_truth  \
# 0   The community is changing with lots of diversi...             0
# 1   I have lived here for over 8 years. I basicall...             1
# 2   I've lived here for almost two years and love ...             1
# 3   I was born and raised in this neighborhood. Th...             1
# 4   The neighborhood I live in is very calm;not to...             1
# 5   I love my neighborhood that is edgy and now, d...             1
# 6   In Bedford- Stuyvesant, I appreciate that many...            -1
# 7   There has already been 2 shootings on my block...             0
# 8   There is a lot of things to see at Bedford-Stu...             1
# 9   I have lived in this area for three years now....             1
# 10  I enjoy the diversity of the neighborhood,  th...             1
# 11  Housing is somewhat expensive however houses s...             1
# 12     People are constently improving the community,             1
# 13      Crime is decreasing however still needs work.             0
# 14           Overall the neighborhood getting better.             0
#
#                                      processed_review
# 0   the community is changing with lots of diversi...
# 1   i have lived here for over  years i basically ...
# 2   ive lived here for almost two years and love h...
# 3   i was born and raised in this neighborhood the...
# 4   the neighborhood i live in is very calmnot too...
# 5   i love my neighborhood that is edgy and now di...
# 6   in bedford stuyvesant i appreciate that many p...
# 7   there has already been  shootings on my block ...
# 8   there is a lot of things to see at bedfordstuy...
# 9   i have lived in this area for three years now ...
# 10  i enjoy the diversity of the neighborhood  the...
# 11  housing is somewhat expensive however houses s...
# 12      people are constently improving the community
# 13       crime is decreasing however still needs work
# 14            overall the neighborhood getting better

# %% [markdown]
# ##### Step 5: Remove the stop words

# %%
# Load stop words
stop_words = set(stopwords.words('english'))

# Function to remove stop words
def remove_stopwords(text):
    word_tokens = word_tokenize(text)
    filtered_sentence = [w for w in word_tokens if not w.lower() in stop_words]
    return " ".join(filtered_sentence)

# Apply the function to remove stop words from 'review content'
df['review_no_stopwords'] = df['processed_review'].apply(remove_stopwords)
df.head(5)
# Out:
#                                  userID          userType  \
# 0  70017df6-e055-4776-8c48-7347a2b2be44  Current Resident
# 1  0c0ff133-4b8b-40a0-ba9d-bbf05eb9d8db  Current Resident
# 2  5f2ee6d6-f1ad-4350-b0b1-bc8ba99177bb  Current Resident
# 3  04ee54e1-8876-4b1e-8d99-336782962398  Current Resident
# 4  5ebe6d64-83d8-49f9-bb46-d3de859bb43d  Current Resident
#
#                    createdTime          categories  rating  \
# 0  2017-05-02T17:05:51.560792Z  Overall Experience       3
# 1  2017-03-28T20:01:57.185719Z  Overall Experience       4
# 2  2017-03-15T00:18:32.329913Z  Overall Experience       5
# 3  2017-02-21T16:13:09.569592Z  Overall Experience       5
# 4  2017-02-01T22:24:32.521606Z  Overall Experience       5
#
#                                               review  ground_truth  \
# 0  The community is changing with lots of diversi...             0
# 1  I have lived here for over 8 years. I basicall...             1
# 2  I've lived here for almost two years and love ...             1
# 3  I was born and raised in this neighborhood. Th...             1
# 4  The neighborhood I live in is very calm;not to...             1
#
#                                     processed_review  \
# 0  the community is changing with lots of diversi...
# 1  i have lived here for over  years i basically ...
# 2  ive lived here for almost two years and love h...
# 3  i was born and raised in this neighborhood the...
# 4  the neighborhood i live in is very calmnot too...
#
#                                  review_no_stopwords
# 0  community changing lots diversity would like s...
# 1  lived years basically grew although neighborho...
# 2  ive lived almost two years love community grow...
# 3  born raised neighborhood neighborhood always h...
# 4  neighborhood live calmnot noisy plethora surro...

# %% [markdown]
# ##### Step 6: Perform sentiment analysis
# ###### (a): Naïve Approach:

# %%
# Load custom lexicons
with open('data/4_sentimentAnalysis/positive-words.txt', 'r') as file:
    positive_words = file.read().splitlines()

with open('data/4_sentimentAnalysis/negative-words.txt', 'r') as file:
    negative_words = file.read().splitlines()

# %%
# Function to assign sentiment based on word counts
def assign_sentiment(review):
    pos_count = sum(word in positive_words for word in review.split())
    neg_count = sum(word in negative_words for word in review.split())

    if pos_count > neg_count:
        return 1
    elif neg_count > pos_count:
        return -1
    else:
        return 0

# Apply the function to the dataframe
df['Sentiment'] = df['review_no_stopwords'].apply(assign_sentiment)

# Display the dataframe with the new Sentiment column
df.head()
# Out:
#                                  userID          userType  \
# 0  70017df6-e055-4776-8c48-7347a2b2be44  Current Resident
# 1  0c0ff133-4b8b-40a0-ba9d-bbf05eb9d8db  Current Resident
# 2  5f2ee6d6-f1ad-4350-b0b1-bc8ba99177bb  Current Resident
# 3  04ee54e1-8876-4b1e-8d99-336782962398  Current Resident
# 4  5ebe6d64-83d8-49f9-bb46-d3de859bb43d  Current Resident
#
#                    createdTime          categories  rating  \
# 0  2017-05-02T17:05:51.560792Z  Overall Experience       3
# 1  2017-03-28T20:01:57.185719Z  Overall Experience       4
# 2  2017-03-15T00:18:32.329913Z  Overall Experience       5
# 3  2017-02-21T16:13:09.569592Z  Overall Experience       5
# 4  2017-02-01T22:24:32.521606Z  Overall Experience       5
#
#                                               review  ground_truth  \
# 0  The community is changing with lots of diversi...             0
# 1  I have lived here for over 8 years. I basicall...             1
# 2  I've lived here for almost two years and love ...             1
# 3  I was born and raised in this neighborhood. Th...             1
# 4  The neighborhood I live in is very calm;not to...             1
#
#                                     processed_review  \
# 0  the community is changing with lots of diversi...
# 1  i have lived here for over  years i basically ...
# 2  ive lived here for almost two years and love h...
# 3  i was born and raised in this neighborhood the...
# 4  the neighborhood i live in is very calmnot too...
#
#                                  review_no_stopwords  Sentiment
# 0  community changing lots diversity would like s...          1
# 1  lived years basically grew although neighborho...          1
# 2  ive lived almost two years love community grow...          1
# 3  born raised neighborhood neighborhood always h...          1
# 4  neighborhood live calmnot noisy plethora surro...          1

# %% [markdown]
# ###### (b) Using HuggingFace (or any other package to implement machine learning techniques for sentiment analysis) and assign a sentiment label to each review

# %%
# Load the sentiment analysis pipeline
# sentiment_pipeline = pipeline('sentiment-analysis')
model_name = "distilbert-base-uncased-finetuned-sst-2-english"
sentiment_pipeline = pipeline("sentiment-analysis", model=model_name)

def get_sentiment(review):
    result = sentiment_pipeline(review)
    label = result[0]['label']
    if label == 'POSITIVE':
        return 1
    elif label == 'NEGATIVE':
        return -1
    else:
        return 0

# Apply the function to the dataframe
df['ML_Sentiment'] = df['review'].apply(get_sentiment)

# %%
df.head(2)
# Out:
#                                  userID          userType  \
# 0  70017df6-e055-4776-8c48-7347a2b2be44  Current Resident
# 1  0c0ff133-4b8b-40a0-ba9d-bbf05eb9d8db  Current Resident
#
#                    createdTime          categories  rating  \
# 0  2017-05-02T17:05:51.560792Z  Overall Experience       3
# 1  2017-03-28T20:01:57.185719Z  Overall Experience       4
#
#                                               review  ground_truth  \
# 0  The community is changing with lots of diversi...             0
# 1  I have lived here for over 8 years. I basicall...             1
#
#                                     processed_review  \
# 0  the community is changing with lots of diversi...
# 1  i have lived here for over  years i basically ...
#
#                                  review_no_stopwords  Sentiment  ML_Sentiment
# 0  community changing lots diversity would like s...          1             1
# 1  lived years basically grew although neighborho...          1             1

# %% [markdown]
# ##### Step 6: Finally, evaluate results by comparing labels with the “ground truth” labels

# %%
# To check the accuracy
correct_predictions = (df['Sentiment'] == df['ground_truth']).sum()
total_predictions = len(df)
accuracy = (correct_predictions / total_predictions) * 100

print(f'Accuracy from Naive approach: {accuracy:.2f}')
# Out:
# Accuracy from Naive approach: 43.96

# %%
# To check the accuracy - ML approach
correct_predictions = (df['ML_Sentiment'] == df['ground_truth']).sum()
total_predictions = len(df)
accuracy = (correct_predictions / total_predictions) * 100

print(f'Accuracy from ML approach: {accuracy:.2f}')
# Out:
# Accuracy from ML approach: 36.23

# %% [markdown]
# ###### With the present approach I believe the Naive approach is better than the ML approach. However, both are pretty bad as the accuracy is just around 40% in either case. Lets try cleaning the data a bit and find a better approach

# %%
# Apply the function to review with stopwords removed
df['ML_Sentiment_no_stopwords'] = df['review_no_stopwords'].apply(get_sentiment)

# To check the accuracy - ML approach
correct_predictions = (df['ML_Sentiment_no_stopwords'] == df['ground_truth']).sum()
total_predictions = len(df)
accuracy = (correct_predictions / total_predictions) * 100

print(f'Accuracy from ML approach with stopwords removed dataframe: {accuracy:.2f}')
# Out:
# Accuracy from ML approach with stopwords removed dataframe: 34.78

# %% [markdown]
# ###### Again a disaster :(
# ###### I think ML might need more datapoints probably to conduct the analysis. So, if there is no limitation on system computational speed and the data is huge then Neural Network would work better and also if the ML's hyper parameter can be fine tuned.
# ###### Naive did better may be because we used domain-specific lexicon that was supplied or say the lexicon was in allignment with the sentiment expression in the given text whereas ML uses a more generalised approach and is not domain specific and might not understand these terms in the context of the reviews.
